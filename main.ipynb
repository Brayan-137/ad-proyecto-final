# %% [markdown]
# ## EDA

# %% [markdown]
# **Base de Videos** (`Base_Videos_Final_202502.csv` / `Base_Videos_Final_202601.csv`)
#
# | Variable | Tipo | Descripción |
# |---|---|---|
# | `frame_idx` | entero | Índice del frame dentro del video del punto |
# | `duration` | decimal | Duración de cada frame en segundos (~0.0167 s = 60 fps) |
# | `total_frames` | entero | Total de frames en el video del punto |
# | `video_duration` | decimal | Duración total del video del punto en segundos |
# | `player_id` | entero | Identificador numérico del jugador en el partido (1–4) |
# | `player_name` | texto | Nombre completo del jugador |
# | `team` | texto | Posición del equipo (top or bottom) |
# | `zone` | texto | Zona de la cancha donde se ubica el jugador: *back_court*, *front_court*, etc. |
# | `ball_position_x` | decimal | Posición horizontal de la pelota en la cancha (metros) |
# | `ball_position_y` | decimal | Posición vertical de la pelota en la cancha (metros) |
# | `player_position_x` | decimal | Posición horizontal del jugador en la cancha (metros) |
# | `player_position_y` | decimal | Posición vertical del jugador en la cancha (metros) |
# | `distance_ball_to_net` | decimal | Distancia de la pelota a la red (metros) |
# | `distance_player_to_ball_m` | decimal | Distancia del jugador a la pelota (metros) |
# | `distance_player_to_net_m` | decimal | Distancia del jugador a la red (metros) |
# | `distance_player_to_teammate_m` | decimal | Distancia del jugador a su compañero de equipo (metros) |
# | `player_hits_ball` | booleano | Si el jugador golpea la pelota en ese frame ('True'/'False' como texto) |
# | `prev_x` | decimal | Posición X del jugador en el frame anterior (metros) |
# | `prev_y` | decimal | Posición Y del jugador en el frame anterior (metros) |
# | `player_displacement` | decimal | Desplazamiento del jugador respecto al frame anterior (metros) |
# | `player_speed_mps` | decimal | Velocidad actual del jugador (metros/segundo) |
# | `prev_speed` | decimal | Velocidad del jugador en el frame anterior (metros/segundo) |
# | `player_acceleration_mps2` | decimal | Aceleración del jugador (metros/segundo²) |
# | `ball_position_x_prev` | decimal | Posición X de la pelota en el frame anterior (metros) |
# | `ball_position_y_prev` | decimal | Posición Y de la pelota en el frame anterior (metros) |
# | `ball_displacement` | decimal | Desplazamiento de la pelota respecto al frame anterior (metros) |
# | `ball_speed_mps` | decimal | Velocidad de la pelota (metros/segundo) |
# | `time_since_last_hit` | decimal | Tiempo transcurrido desde el último golpe del jugador (segundos) |
# | `partido` | entero | Identificador del partido al que pertenece el frame |
# | `punto` | entero | Identificador del punto dentro del partido |
#
# ---
#
# **Traza de Datos de Partidos** (`Traza_Datos_Partidos_202502.xlsx` / `_202601.xlsx` · 2 hojas: Cancha 1 y Cancha 2)
#
# | Variable | Tipo | Descripción |
# |---|---|---|
# | `ID_PARTIDO` | entero | Identificador único del partido |
# | `CANCHA` | entero | Número de la cancha donde se jugó (1 o 2) |
# | `ID_PUNTO` | entero | Número de secuencia del punto dentro del partido |
# | `ID_JUGADOR_1_EQUIPO_1` | texto | Nombre del jugador 1 del equipo 1 |
# | `ID_JUGADOR_2_EQUIPO_1` | texto | Nombre del jugador 2 del equipo 1 |
# | `ID_JUGADOR_1_EQUIPO_2` | texto | Nombre del jugador 1 del equipo 2 |
# | `ID_JUGADOR_2_EQUIPO_2` | texto | Nombre del jugador 2 del equipo 2 |
# | `EQUIPO_1_POSICION` | texto | Posición general del equipo 1 en la cancha: *BOTTOM* o *TOP* |
# | `EQUIPO_2_POSICION` | texto | Posición general del equipo 2 en la cancha: *BOTTOM* o *TOP* |
# | `POSICION_JUGADOR_1_EQUIPO_1` | texto | Lado de la cancha del jugador 1 equipo 1: *LEFT* o *RIGHT* |
# | `POSICION_JUGADOR_2_EQUIPO_1` | texto | Lado de la cancha del jugador 2 equipo 1: *LEFT* o *RIGHT* |
# | `POSICION_JUGADOR_1_EQUIPO_2` | texto | Lado de la cancha del jugador 1 equipo 2: *LEFT* o *RIGHT* |
# | `POSICION_JUGADOR_2_EQUIPO_2` | texto | Lado de la cancha del jugador 2 equipo 2: *LEFT* o *RIGHT* |
# | `PUNTO_EQUIPO_1` | entero | Si el equipo 1 ganó el punto (1 = ganó, 0 = perdió) |
# | `PUNTO_EQUIPO_2` | entero | Si el equipo 2 ganó el punto (1 = ganó, 0 = perdió) |
#
# ---
#
# **Datos de Jugadores** (`Datos_Jugadores_Padel_202502.xlsx` / `Data_Jugadores_202601.xlsx`)
#
# | Variable | Tipo | Descripción |
# |---|---|---|
# | `Marca temporal` | fecha | Fecha y hora en que se diligenció el formulario |
# | `NOMBRE` | texto | Nombre completo del jugador (clave de enlace con la traza de partidos) |
# | `CODIGO_ESTUDIANTE` | texto | Código institucional del estudiante |
# | `CIUDAD` | texto | Ciudad de residencia del jugador |
# | `EDAD` | entero | Edad del jugador en años |
# | `GENERO` | texto | Género del jugador |
# | `PROGRAMA_ACADEMICO` | texto | Programa universitario que cursa |
# | `SEMESTRE` | entero | Semestre académico actual |
# | `EXPERIENCIA_PADEL` | texto | Si tiene experiencia previa en pádel (Sí/No) |
# | `TIEMPO_JUGANDO_PADEL` | texto | Tiempo aproximado que lleva practicando pádel |
# | `PRACTICA_OTRO_DEPORTE_RAQUETA` | texto | Si practica otro deporte de raqueta (tenis, squash, etc.) |
# | `NIVEL_ACTUAL_PADEL` | texto | Nivel de juego autorreportado (principiante, intermedio, avanzado) |
# | `ESTADO_FISICO` | texto | Percepción del jugador sobre su condición física actual |
# | `FRECUENCIA_DEPORTE` | texto | Frecuencia semanal con la que practica deporte en general |
# | `ESTATURA` | decimal | Estatura del jugador (verificar unidades: metros o centímetros) |
# | `TALLA` | texto | Talla de ropa del jugador (S, M, L, XL, etc.) |
# | `MANO_DOMINANTE` | texto | Mano dominante: derecha o izquierda |
# | `RITMO_CARDIACO` | entero | Frecuencia cardíaca en reposo (ppm) |
# | `LESIONES_LY` | texto | Si tuvo lesiones en el último año |
# | `RAZON_PARTICIPACION` | texto | Motivo por el que participa en la actividad |
# | `OBJETIVO_ACTIVIDAD` | texto | Objetivo personal con la actividad deportiva |
# | `INTERES_PADEL` | texto | Nivel de interés en el pádel como deporte |
# | `CLASES_PADEL` | texto | Si ha tomado clases formales de pádel |
# | `DESAYUNO` | texto | Si desayunó el día de la actividad (Sí/No) |
# | `¿Que desayunaste?` | texto | Descripción abierta de lo que desayunó |
# | `GENERO_MUSICAL_FAVORITO` | texto | Género musical favorito (dato contextual) |
# | `COMENTARIOS` | texto | Observaciones adicionales en texto libre |
# | `Puntos_Ganados` | entero | Total de puntos ganados en todos sus partidos |
# | `Puntos_Jugados` | entero | Total de puntos disputados |
# | `Win_Rate` | decimal | Tasa de éxito: Puntos_Ganados / Puntos_Jugados (0 a 1) |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Cargar el dataset
data_videos = pd.read_csv("./databases/2026-1/Base_Videos_Final_202601.csv")
data_partidos = pd.read_excel("./databases/2026-1/Traza_Datos_Partidos_202601.xlsx")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### LIMPIEZA DE LOS DATOS

# %% [markdown]
# #### data_videos

# %% [markdown]
# ##### Valores nulos

# %% [markdown]
# **Detección**

# %%
data_videos.info()
# Out:
#         frame_idx  duration  total_frames  video_duration  player_id  \
# 347832         64     0.017           781          13.005          1
# 202054        135     0.017           374           6.233          1
# 255269        642     0.017           800          13.342          1
# 103464        343     0.017           846          14.100          1
# 214974        280     0.017           300           5.000          1
# 349113        741     0.017           781          13.005          2
# 346375        476     0.017           707          11.793          2
# 156771         96     0.017           879          14.662          8
# 62994         722     0.017          1693          28.239          2
# 333997         61     0.017           298           4.972          1
# 22994         794     0.017          1197          19.966          1
# 170746       1405     0.017          1526          25.454          2
# 73124         365     0.017          2293          38.247          2
# 309066        494     0.017           561           9.359          1
# 181993        671     0.017          1500          25.000          2
# 302647         63     0.033           206           6.867          1
# 402290        333     0.017           646          10.767          1
# 61870        1222     0.017          1693          28.239          1
# 163960         90     0.017          1942          32.393          2
# 219189        441     0.017          1393          23.237          1
#
#                             player_name    team        zone  ball_position_x  \
# 347832       Luis Felipe Bonilla Patiño  bottom  back_court            4.800
# 202054   Luis Felipe Cuellar Santamaria  bottom    left_box            8.880
# 255269       Luis Felipe Bonilla Patiño  bottom   right_box            4.360
# 103464                        Juan Guio  bottom  back_court            4.800
# 214974   Luis Felipe Cuellar Santamaria  bottom    left_box            2.440
# 349113                        Pia Aroor  bottom  back_court            2.760
# 346375                        Pia Aroor  bottom  back_court            4.160
# 156771                         Player_8     top    left_box            6.360
# 62994   Samuel Francisco Rubio Casallas     top    left_box            6.920
# 333997                     Jorge Garcia  bottom   right_box            1.400
# 22994              Laura Natalia Garcia  bottom   right_box            3.640
# 170746              Juan Felipe Mahecha  bottom   right_box            7.400
# 73124   Samuel Francisco Rubio Casallas     top    left_box            1.800
# 309066                        Pia Aroor  bottom    left_box            8.520
# 181993                        Juan Guio  bottom   right_box            3.000
# 302647             Laura Natalia Garcia  bottom  back_court            6.520
# 402290          YEISON DAVID NINO ARIAS  bottom   right_box            6.760
# 61870                 Isabella Buitrago  bottom   right_box            6.400
# 163960              Juan Felipe Mahecha     top   right_box            6.400
# 219189            Esteban Sequeda Henao     top    left_box            8.640
#
#         ball_position_y  player_position_x  player_position_y  \
# 347832           18.711              3.800              3.800
# 202054            1.200              6.920              6.920
# 255269           10.711              7.720              7.720
# 103464            9.067              7.080              7.080
# 214974            5.778              4.520              4.520
# 349113            6.044              7.520              7.520
# 346375           17.600              7.720              7.720
# 156771           16.267              6.800              6.800
# 62994            16.800              6.880              6.880
# 333997           12.178              6.400              6.400
# 22994             6.000              2.600              2.600
# 170746            7.911              2.040              2.040
# 73124            12.756              7.440              7.440
# 309066           16.311              4.160              4.160
# 181993            9.822              5.520              5.520
# 302647           16.844              2.760              2.760
# 402290           11.111              5.800              5.800
# 61870            16.267              2.680              2.680
# 163960           16.311              3.720              3.720
# 219189            8.133              7.760              7.760
#
#         distance_ball_to_net  distance_player_to_ball_m  \
# 347832                 8.711                      1.009
# 202054                 8.800                      3.382
# 255269                 0.711                      6.266
# 103464                 0.933                      8.575
# 214974                 4.222                     10.171
# 349113                 3.956                     12.210
# 346375                 7.600                      3.574
# 156771                 6.267                     12.141
# 62994                  6.800                     11.911
# 333997                 2.178                      5.223
# 22994                  4.000                      1.368
# 170746                 2.089                      5.967
# 73124                  2.756                     10.303
# 309066                 6.311                      4.433
# 181993                 0.178                      7.419
# 302647                 6.844                      3.762
# 402290                 1.111                      2.139
# 61870                  6.267                     13.586
# 163960                 6.311                     12.904
# 219189                 1.867                      2.473
#
#         distance_player_to_net_m  distance_player_to_teammate_m  \
# 347832                     8.578                          3.643
# 202054                     6.044                          3.727
# 255269                     6.000                          0.000
# 103464                     7.333                          4.561
# 214974                     5.733                          3.055
# 349113                     7.289                          3.640
# 346375                     7.289                          4.056
# 156771                     5.867                          4.186
# 62994                      5.111                          5.830
# 333997                     3.689                          0.000
# 22994                      4.889                         10.000
# 170746                     4.711                          6.336
# 73124                      5.867                          5.344
# 309066                     5.511                          1.899
# 181993                     6.800                          1.682
# 302647                     6.978                          4.172
# 402290                     3.022                          4.751
# 61870                      6.800                          5.078
# 163960                     6.311                          0.625
# 219189                     4.178                          5.016
#
#         player_hits_ball  prev_x  prev_y  player_displacement  \
# 347832             False   3.800   3.800                0.000
# 202054             False   6.920   6.920                0.000
# 255269             False   7.760   7.760                0.057
# 103464             False   7.000   7.000                0.113
# 214974             False   4.520   4.520                0.000
# 349113             False   7.520   7.520                0.000
# 346375             False   7.720   7.720                0.000
# 156771             False   6.800   6.800                0.000
# 62994              False   6.880   6.880                0.000
# 333997             False   6.400   6.400                0.000
# 22994              False   2.600   2.600                0.000
# 170746             False   1.960   1.960                0.113
# 73124              False   7.440   7.440                0.000
# 309066             False   4.160   4.160                0.000
# 181993             False   5.520   5.520                0.000
# 302647             False   2.760   2.760                0.000
# 402290             False   5.800   5.800                0.000
# 61870              False   2.680   2.680                0.000
# 163960             False   3.760   3.760                0.057
# 219189             False   7.720   7.720                0.057
#
#         player_speed_mps  prev_speed  player_acceleration_mps2  \
# 347832             0.000       0.000                     0.000
# 202054             0.000       0.000                     0.000
# 255269             3.392       0.000                    10.000
# 103464             6.788       3.394                    10.000
# 214974             0.000       0.000                     0.000
# 349113             0.000       0.000                     0.000
# 346375             0.000       0.000                     0.000
# 156771             0.000       0.000                     0.000
# 62994              0.000       3.391                   -10.000
# 333997             0.000       0.000                     0.000
# 22994              0.000       0.000                     0.000
# 170746             6.783      27.131                   -10.000
# 73124              0.000       0.000                     0.000
# 309066             0.000       0.000                     0.000
# 181993             0.000       0.000                     0.000
# 302647             0.000       1.697                   -10.000
# 402290             0.000       0.000                     0.000
# 61870              0.000       3.391                   -10.000
# 163960             3.391       0.000                    10.000
# 219189             3.391       0.000                    10.000
#
#         ball_position_x_prev  ball_position_y_prev  ball_displacement  \
# 347832                 4.800                18.711              0.000
# 202054                 8.880                 1.200              0.000
# 255269                 4.440                10.667              0.092
# 103464                 4.800                 9.067              0.000
# 214974                 2.440                 5.778              0.000
# 349113                 2.760                 6.044              0.000
# 346375                 4.160                17.600              0.000
# 156771                 6.360                16.267              0.000
# 62994                  6.920                16.800              0.000
# 333997                 1.400                12.222              0.044
# 22994                  3.640                 6.000              0.000
# 170746                 7.400                 7.911              0.000
# 73124                  1.800                12.756              0.000
# 309066                 7.760                15.644              1.011
# 181993                 3.000                 9.822              0.000
# 302647                 6.520                16.844              0.000
# 402290                 6.760                11.156              0.044
# 61870                  6.320                15.956              0.321
# 163960                 6.400                16.311              0.000
# 219189                 8.640                 8.133              0.000
#
#         ball_speed_mps  time_since_last_hit  partido  punto
# 347832           0.000               -1.000       31     12
# 202054           0.000               -1.000       12      1
# 255269           5.488               -1.000       18      5
# 103464           0.000               -1.000        6     11
# 214974           0.000               -1.000       12     10
# 349113           0.000               -1.000       31     12
# 346375           0.000               -1.000       31     11
# 156771           0.000                1.051        9      4
# 62994            0.000               -1.000        5      4
# 333997           2.664               -1.000       30     13
# 22994            0.000               -1.000        3      5
# 170746           0.000               -1.000        9      7
# 73124            0.000               -1.000        5      6
# 309066          50.000               -1.000       27      4
# 181993           0.000               -1.000       10      1
# 302647           0.000               -1.000       25      8
# 402290           2.667               -1.000       36      6
# 61870           19.258               -1.000        5      4
# 163960           0.000               -1.000        9      6
# 219189           0.000               -1.000       15      1

# %% [markdown]
# **Hallazgos**
#
# - Hay frames en los cuales el equipo no es detectado team (la posición del equipo top or bottom) -> Al no cambiar durante la duración del punto el partido, se reemplazara con la media de ese punto o partido
# - Hay casos en los que la distancia al compañero del jugador esta calculada en solo uno de los dos miembros del equipo -> Revisar la existencia de esos casos y corregirlo; En caso de que no pero se tengan las posiciones de los dos jugadores calcularlo para amos
# - Los valores nulos de las variables prev_x, prev_y, player_displacement, player_speed, prev_speed, player_acceleration, ball_position_x_prev, ball_position_y_prev, ball_displacement, ball_speed_mps, son nulos en los primeros frames de cada punto -> Se plantea eliminar las filas de estos primeros frames
# - Los valores nulos de las variables ball_position_x_prev, ball_position_y_prev, ball_displacement, ball_speed_mps que no son el primer frame no son calculadas -> Revisar si se cuenta con las posiciones de la pelota y corregirlo
# - time_since_last_hit es nulo si al principio de cada punto hasta que no se golpee por primera vez -> imputar con -1, indica que no ha sido golpeado todavia
# - tras una primera limpieza de los primeros frames quedarón apenas 285 nulos en las variables de ball_position_x_prev, ball_position_y_prev, ball_displacement, ball_speed_mps -> al ser tan pocos se opto por su eliminación

# %% [markdown]
# **Tratamiento**

# %%
# ============================================================
# TRATAMIENTO DE VALORES NULOS - data_videos
# ============================================================

# ------------------------------------------------------------
# 1. Eliminar primeros frames de cada punto
# ------------------------------------------------------------
data_videos = data_videos[data_videos['frame_idx'] != 0].reset_index(drop=True)

# Eliminar nulos residuales en prev_speed y player_acceleration_mps2
# (frame 1 de cada punto, que necesitaba frame 0 como referencia)
data_videos = data_videos.dropna(
    subset=['prev_speed', 'player_acceleration_mps2']
).reset_index(drop=True)

# ------------------------------------------------------------
# 2. Imputar time_since_last_hit con -1
# ------------------------------------------------------------
data_videos['time_since_last_hit'] = data_videos['time_since_last_hit'].fillna(-1)

# ------------------------------------------------------------
# 3. Imputar team con la moda (punto -> partido -> jugador)
# ------------------------------------------------------------
def imputar_moda(series):
    moda = series.dropna().mode()
    return series.fillna(moda[0] if not moda.empty else np.nan)

# Nivel 1: moda por punto y jugador
data_videos['team'] = (
    data_videos
    .groupby(['partido', 'punto', 'player_id'])['team']
    .transform(imputar_moda)
)

# Nivel 2: moda por partido y jugador
data_videos['team'] = (
    data_videos
    .groupby(['partido', 'player_id'])['team']
    .transform(imputar_moda)
)

# Nivel 3: moda global por jugador (across todos sus partidos)
data_videos['team'] = (
    data_videos
    .groupby('player_name')['team']
    .transform(imputar_moda)
)

# Eliminar nulos residuales de team
data_videos = data_videos.dropna(subset=['team']).reset_index(drop=True)

# ------------------------------------------------------------
# 4. Imputar distance_player_to_teammate_m (sin merge)
# ------------------------------------------------------------
data_videos = data_videos.sort_values(
    ['partido', 'punto', 'frame_idx', 'team', 'player_id']
).reset_index(drop=True)

# Dentro de cada frame y equipo, el compañero es el otro jugador
# shift(1) y shift(-1) dan la posición del otro miembro del equipo
grp_equipo = data_videos.groupby(['partido', 'punto', 'frame_idx', 'team'])

companero_x = grp_equipo['player_position_x'].transform(
    lambda g: g.iloc[::-1].values  # invierte el par [j1, j2] -> [j2, j1]
)
companero_y = grp_equipo['player_position_y'].transform(
    lambda g: g.iloc[::-1].values
)

distancia_calculada = np.sqrt(
    (data_videos['player_position_x'] - companero_x)**2 +
    (data_videos['player_position_y'] - companero_y)**2
)

data_videos['distance_player_to_teammate_m'] = data_videos[
    'distance_player_to_teammate_m'
].fillna(distancia_calculada)

print("Shape después del paso 4:", data_videos.shape)

# ------------------------------------------------------------
# 5. Recalcular variables de pelota donde sean nulas
# ------------------------------------------------------------
data_videos = data_videos.sort_values(
    ['partido', 'punto', 'player_id', 'frame_idx']
).reset_index(drop=True)

grp = data_videos.groupby(['partido', 'punto', 'player_id'])

data_videos['ball_position_x_prev'] = data_videos['ball_position_x_prev'].fillna(
    grp['ball_position_x'].shift(1)
)
data_videos['ball_position_y_prev'] = data_videos['ball_position_y_prev'].fillna(
    grp['ball_position_y'].shift(1)
)

ball_disp_calculado = np.sqrt(
    (data_videos['ball_position_x'] - data_videos['ball_position_x_prev'])**2 +
    (data_videos['ball_position_y'] - data_videos['ball_position_y_prev'])**2
)
data_videos['ball_displacement'] = data_videos['ball_displacement'].fillna(
    ball_disp_calculado
)

data_videos['ball_speed_mps'] = data_videos['ball_speed_mps'].fillna(
    data_videos['ball_displacement'] / data_videos['duration']
)

# Eliminar nulos residuales de variables de pelota (0.08% de los datos)
data_videos = data_videos.dropna(subset=[
    'ball_position_x_prev',
    'ball_position_y_prev',
    'ball_displacement',
    'ball_speed_mps'
]).reset_index(drop=True)

# ------------------------------------------------------------
# Verificación final
# ------------------------------------------------------------
nulos = data_videos.isnull().sum()
nulos_restantes = nulos[nulos > 0]

if nulos_restantes.empty:
    print("\nSin nulos restantes")
else:
    print("\nNulos restantes por columna:")
    print(nulos_restantes)

print(f"\nShape final: {data_videos.shape}")
# Out:
# Shape después del paso 4: (431422, 30)
#
# Sin nulos restantes
#
# Shape final: (431122, 30)

# %% [markdown]
# ##### Outliers

# %% [markdown]
# **Detección**

# %% [markdown]
# Para el detección de los outliers se realizó una comparación utilizando el rango inerquartilico y unos límitos físicos previamente definidos, esto debido a que varias variables como player_speed_mps, player_acceleration_mps2, ball_speed_mps, ball_displacement y player_displacement en su mayoría de valores son iguales a cero afectando su capacidad para definir unos límites inferiores y superiore fiables, como se puede ver a continuación:

# %%
# ============================================================
# DETECCIÓN DE OUTLIERS - Comparación IQR vs Límites Físicos
# ============================================================

vars_numericas = [
    'player_speed_mps', 'player_acceleration_mps2',
    'ball_speed_mps', 'ball_displacement',
    'distance_player_to_ball_m', 'distance_player_to_net_m',
    'distance_player_to_teammate_m', 'player_displacement'
]

limites_fisicos = {
    'player_speed_mps':              (0, 7),
    'player_acceleration_mps2':      (-10, 10),
    'ball_speed_mps':                (0, 50),
    'ball_displacement':             (0, 20),
    'distance_player_to_ball_m':     (0, 20),
    'distance_player_to_net_m':      (0, 10),
    'distance_player_to_teammate_m': (0, 10),
    'player_displacement':           (0, 2),
}

resultados = []

for col in vars_numericas:
    # --- IQR (3x) ---
    Q1 = data_videos[col].quantile(0.25)
    Q3 = data_videos[col].quantile(0.75)
    IQR = Q3 - Q1
    lim_iqr_inf = Q1 - 3 * IQR
    lim_iqr_sup = Q3 + 3 * IQR
    mask_iqr = (data_videos[col] < lim_iqr_inf) | (data_videos[col] > lim_iqr_sup)
    n_iqr = mask_iqr.sum()

    # --- Límites físicos ---
    min_fis, max_fis = limites_fisicos[col]
    mask_fis = (data_videos[col] < min_fis) | (data_videos[col] > max_fis)
    n_fis = mask_fis.sum()

    # --- Solo IQR / Solo físico / Ambos ---
    solo_iqr  = (mask_iqr & ~mask_fis).sum()
    solo_fis  = (mask_fis & ~mask_iqr).sum()
    ambos     = (mask_iqr & mask_fis).sum()

    resultados.append({
        'variable':          col,
        'min_real':          data_videos[col].min(),
        'max_real':          data_videos[col].max(),
        'lim_iqr_inf':       lim_iqr_inf,
        'lim_iqr_sup':       lim_iqr_sup,
        'lim_fis_inf':       min_fis,
        'lim_fis_sup':       max_fis,
        'outliers_iqr':      n_iqr,
        'outliers_iqr_%':    round(n_iqr / len(data_videos) * 100, 3),
        'outliers_fis':      n_fis,
        'outliers_fis_%':    round(n_fis / len(data_videos) * 100, 3),
        'solo_iqr':          solo_iqr,
        'solo_fisico':       solo_fis,
        'ambos':             ambos,
    })

df_comparacion = pd.DataFrame(resultados).set_index('variable')

pd.set_option('display.float_format', '{:.3f}'.format)
print("=== Comparación IQR vs Límites Físicos ===\n")
print(df_comparacion.to_string())
# Out:
# === Comparación IQR vs Límites Físicos ===
#
#                                 min_real  max_real  lim_iqr_inf  lim_iqr_sup  lim_fis_inf  lim_fis_sup  outliers_iqr  outliers_iqr_%  outliers_fis  outliers_fis_%  solo_iqr  solo_fisico   ambos
# variable
# player_speed_mps                   0.000   562.860        0.000        0.000            0            7         75689          17.556          5233           1.214     70456            0    5233
# player_acceleration_mps2      -33534.611 33534.611        0.000        0.000          -10           10        120197          27.880        117085          27.158      3112            0  117085
# ball_speed_mps                     0.000   976.108        0.000        0.000            0           50         83472          19.362          2906           0.674     80566            0    2906
# ball_displacement                  0.000    16.285        0.000        0.000            0           20         83472          19.362             0           0.000     83472            0       0
# distance_player_to_ball_m          0.040    24.599      -14.013       29.053            0           20             0           0.000           785           0.182         0          785       0
# distance_player_to_net_m           0.000    15.467       -0.889       13.733            0           10           487           0.113          5711           1.325         0         5224     487
# distance_player_to_teammate_m      0.000    19.787       -2.605       11.567            0           10         39783           9.228         51732          11.999         0        11949   39783
# player_displacement                0.000     9.390        0.000        0.000            0            2         75689          17.556          1917           0.445     73772            0    1917

# %% [markdown]
# **Hallazgos**
#
# Como se comentó, en varias de estar variables, los limites que definió el rango interquartilico fueron cero o incluso valores negativos en el caso de las distancias.

# %% [markdown]
# **Tratamiento**

# %%
# ============================================================
# TRATAMIENTO DE OUTLIERS - Clipeo por límites físicos
# ============================================================

for col, (min_val, max_val) in limites_fisicos.items():
    if col == 'ball_displacement':
        continue  # sin outliers reales
    data_videos[col] = data_videos[col].clip(lower=min_val, upper=max_val)

# Verificación
print("=== Verificación post-clipeo ===")
for col, (min_val, max_val) in limites_fisicos.items():
    real_min = data_videos[col].min()
    real_max = data_videos[col].max()
    ok = "OK" if real_min >= min_val and real_max <= max_val else "REVISAR"
    print(f"{ok} | {col}: [{real_min:.3f}, {real_max:.3f}]")
# Out:
# === Verificación post-clipeo ===
# OK | player_speed_mps: [0.000, 7.000]
# OK | player_acceleration_mps2: [-10.000, 10.000]
# OK | ball_speed_mps: [0.000, 50.000]
# OK | ball_displacement: [0.000, 16.285]
# OK | distance_player_to_ball_m: [0.040, 20.000]
# OK | distance_player_to_net_m: [0.000, 10.000]
# OK | distance_player_to_teammate_m: [0.000, 10.000]
# OK | player_displacement: [0.000, 2.000]

# %% [markdown]
# ### data_partidos

# %% [markdown]
# #### Valores nulos

# %% [markdown]
# **Detección**

# %%
print(data_partidos.shape)
data_partidos.info()
# Out:
# (200, 15)
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID_PARTIDO                   200 non-null    int64
#  1   CANCHA                       200 non-null    int64
#  2   ID_PUNTO                     200 non-null    int64
#  3   ID_JUGADOR_1_EQUIPO_1        200 non-null    str
#  4   ID_JUGADOR_2_EQUIPO_1        200 non-null    str
#  5   ID_JUGADOR_1_EQUIPO_2        200 non-null    str
#  6   ID_JUGADOR_2_EQUIPO_2        200 non-null    str
#  7   EQUIPO_1_POSICION            200 non-null    str
#  8   EQUIPO_2_POSICION            200 non-null    str
#  9   POSICION_JUGADOR_1_EQUIPO_1  200 non-null    str
#  10  POSICION_JUGADOR_2_EQUIPO_1  200 non-null    str
#  11  POSICION_JUGADOR_1_EQUIPO_2  200 non-null    str
#  12  POSICION_JUGADOR_2_EQUIPO_2  200 non-null    str
#  13  PUNTO_EQUIPO_1               200 non-null    int64
#  14  PUNTO_EQUIPO_2               200 non-null    int64
# dtypes: int64(5), str(10)
# memory usage: 23.6 KB

# %%
data_partidos.sample(20)
# Out:
#      ID_PARTIDO  CANCHA  ID_PUNTO             ID_JUGADOR_1_EQUIPO_1  \
# 104          21       1         4                     Natalia Perez
# 126          25       1         3          César Camilo Díaz Cufiño
# 94           19       1         4                     Juliana Gomez
# 31            5       1        10                 Isabella Buitrago
# 93           19       1         3                     Juliana Gomez
# 15            3       1         5                  Juan David Rubio
# 26            5       1         5                 Isabella Buitrago
# 61           13       1         2             SANTIAGO PEÑA BELTRAN
# 114          23       1         4  Daniel Esteban Ortegon Jaramillo
# 162          31       1         9                         Pia Aroor
# 84           17       1         3                  Juan David Rubio
# 90           17       1         9                  Juan David Rubio
# 11            3       1         1                  Juan David Rubio
# 85           17       1         4                  Juan David Rubio
# 108          21       1         8                     Natalia Perez
# 152          29       1        11      Juan sebastian melo gonzalez
# 129          25       1         6          César Camilo Díaz Cufiño
# 147          29       1         6      Juan sebastian melo gonzalez
# 86           17       1         5                  Juan David Rubio
# 44            9       1         3  Daniel Esteban Ortegon Jaramillo
#
#                  ID_JUGADOR_2_EQUIPO_1          ID_JUGADOR_1_EQUIPO_2  \
# 104                  Sofia Daza García          Tiffany Cardona Perez
# 126               Laura Natalia Garcia            Sergio Gomez Osorio
# 94             Juan david Ortiz rendon          Mateo Ramírez Cabrera
# 31     Samuel Francisco Rubio Casallas          Mateo Ramírez Cabrera
# 93             Juan david Ortiz rendon          Mateo Ramírez Cabrera
# 15               SANTIAGO PEÑA BELTRAN      Alejandra Salazar Galeano
# 26     Samuel Francisco Rubio Casallas          Mateo Ramírez Cabrera
# 61           Carlos Andrés Díaz Méndez            Andre Leonard Duque
# 114                Juan Felipe Mahecha          Tiffany Cardona Perez
# 162         Luis Felipe Bonilla Patiño          Carlos Felipe Andrade
# 84       Sahily Andrea Herrera Eljadue              Isabella Buitrago
# 90       Sahily Andrea Herrera Eljadue              Isabella Buitrago
# 11               SANTIAGO PEÑA BELTRAN      Alejandra Salazar Galeano
# 85       Sahily Andrea Herrera Eljadue              Isabella Buitrago
# 108                  Sofia Daza García          Tiffany Cardona Perez
# 152          Alejandra Salazar Galeano  Sahily Andrea Herrera Eljadue
# 129               Laura Natalia Garcia            Sergio Gomez Osorio
# 147          Alejandra Salazar Galeano  Sahily Andrea Herrera Eljadue
# 86       Sahily Andrea Herrera Eljadue              Isabella Buitrago
# 44   Gabriel Alejandro Corzo Fernández          Esteban Sequeda Henao
#
#                ID_JUGADOR_2_EQUIPO_2 EQUIPO_1_POSICION EQUIPO_2_POSICION  \
# 104  Samuel Francisco Rubio Casallas            BOTTOM               TOP
# 126     Juan sebastian melo gonzalez            BOTTOM               TOP
# 94                Nicolas Navarro D.            BOTTOM               TOP
# 31       Maria Jose Palomino Carreño               TOP            BOTTOM
# 93                Nicolas Navarro D.            BOTTOM               TOP
# 15              Laura Natalia Garcia            BOTTOM               TOP
# 26       Maria Jose Palomino Carreño               TOP            BOTTOM
# 61                Juan David Quitian            BOTTOM               TOP
# 114            Esteban Sequeda Henao            BOTTOM               TOP
# 162             Laura Natalia Garcia            BOTTOM               TOP
# 84                         Pia Aroor            BOTTOM               TOP
# 90                         Pia Aroor            BOTTOM               TOP
# 11              Laura Natalia Garcia            BOTTOM               TOP
# 85                         Pia Aroor            BOTTOM               TOP
# 108  Samuel Francisco Rubio Casallas            BOTTOM               TOP
# 152  Samuel Francisco Rubio Casallas            BOTTOM               TOP
# 129     Juan sebastian melo gonzalez            BOTTOM               TOP
# 147  Samuel Francisco Rubio Casallas            BOTTOM               TOP
# 86                         Pia Aroor            BOTTOM               TOP
# 44               Juan Felipe Mahecha            BOTTOM               TOP
#
#     POSICION_JUGADOR_1_EQUIPO_1 POSICION_JUGADOR_2_EQUIPO_1  \
# 104                        LEFT                       RIGHT
# 126                       RIGHT                        LEFT
# 94                        RIGHT                        LEFT
# 31                         LEFT                       RIGHT
# 93                        RIGHT                        LEFT
# 15                        RIGHT                        LEFT
# 26                         LEFT                       RIGHT
# 61                        RIGHT                        LEFT
# 114                       RIGHT                        LEFT
# 162                       RIGHT                        LEFT
# 84                        RIGHT                        LEFT
# 90                        RIGHT                        LEFT
# 11                        RIGHT                        LEFT
# 85                        RIGHT                        LEFT
# 108                        LEFT                       RIGHT
# 152                       RIGHT                        LEFT
# 129                       RIGHT                        LEFT
# 147                       RIGHT                        LEFT
# 86                        RIGHT                        LEFT
# 44                        RIGHT                        LEFT
#
#     POSICION_JUGADOR_1_EQUIPO_2 POSICION_JUGADOR_2_EQUIPO_2  PUNTO_EQUIPO_1  \
# 104                        LEFT                       RIGHT               1
# 126                       RIGHT                        LEFT               0
# 94                        RIGHT                        LEFT               0
# 31                         LEFT                       RIGHT               1
# 93                        RIGHT                        LEFT               0
# 15                        RIGHT                        LEFT               1
# 26                         LEFT                       RIGHT               0
# 61                         LEFT                       RIGHT               1
# 114                       RIGHT                        LEFT               1
# 162                       RIGHT                        LEFT               0
# 84                        RIGHT                        LEFT               1
# 90                        RIGHT                        LEFT               1
# 11                        RIGHT                        LEFT               0
# 85                        RIGHT                        LEFT               1
# 108                        LEFT                       RIGHT               0
# 152                       RIGHT                        LEFT               1
# 129                       RIGHT                        LEFT               0
# 147                       RIGHT                        LEFT               1
# 86                        RIGHT                        LEFT               1
# 44                        RIGHT                        LEFT               0
#
#      PUNTO_EQUIPO_2
# 104               0
# 126               1
# 94                1
# 31                0
# 93                1
# 15                0
# 26                1
# 61                0
# 114               0
# 162               1
# 84                0
# 90                0
# 11                1
# 85                0
# 108               1
# 152               0
# 129               1
# 147               0
# 86                0
# 44                1

# %% [markdown]
# **Hallazgos**
#
# No se encontró ningún dato nulo

# %% [markdown]
# #### Outliers

# %% [markdown]
# **Detección**

# %% [markdown]
# Todas las variables de esta base de datos son indices y variables categoricas. Teniendo esto en cuenta, lo que quedaba por revisar era el formato y las categorias de estas variables.

# %% [markdown]
# **Hallazgos**
#
# - No se encontrarón valores que sobresalieran de las categorías que se esperaban.
# - Sim embago, los nombres de algunos participantes tenian un formato diferente al de los demás (todo en mayúsculas), por lo cual se procede a formatear estas celdas.

# %% [markdown]
# **Tratamiento**

# %%
# ============================================================
# FORMATEO DE NOMBRES DE JUGADORES - data_partidos
# ============================================================

cols_jugadores = [
    'ID_JUGADOR_1_EQUIPO_1',
    'ID_JUGADOR_2_EQUIPO_1',
    'ID_JUGADOR_1_EQUIPO_2',
    'ID_JUGADOR_2_EQUIPO_2'
]

for col in cols_jugadores:
    data_partidos[col] = data_partidos[col].str.strip().str.title()

# Verificación
print("=== Muestra post-formateo ===")
print(data_partidos[cols_jugadores].drop_duplicates().to_string())
# Out:
# === Muestra post-formateo ===
#                  ID_JUGADOR_1_EQUIPO_1              ID_JUGADOR_2_EQUIPO_1              ID_JUGADOR_1_EQUIPO_2            ID_JUGADOR_2_EQUIPO_2
# 0            Alejandra Salazar Galeano       Ángel Santiago Toribio Godoy              Santiago Peña Beltran    Sahily Andrea Herrera Eljadue
# 11                    Juan David Rubio              Santiago Peña Beltran          Alejandra Salazar Galeano             Laura Natalia Garcia
# 22                   Isabella Buitrago    Samuel Francisco Rubio Casallas              Mateo Ramírez Cabrera      Maria Jose Palomino Carreño
# 33           Juan Esteban Bustos Marín                  Sofia Daza García  Gabriel Alejandro Corzo Fernández     Ángel Santiago Toribio Godoy
# 42    Daniel Esteban Ortegon Jaramillo  Gabriel Alejandro Corzo Fernández              Esteban Sequeda Henao              Juan Felipe Mahecha
# 51   Gabriel Alejandro Corzo Fernández                          Pia Aroor           César Camilo Díaz Cufiño                Isabella Buitrago
# 60               Santiago Peña Beltran          Carlos Andrés Díaz Méndez                Andre Leonard Duque               Juan David Quitian
# 71                        Jorge Garcia            Juan David Ortiz Rendon              Esteban Sequeda Henao         César Camilo Díaz Cufiño
# 82                    Juan David Rubio      Sahily Andrea Herrera Eljadue                  Isabella Buitrago                        Pia Aroor
# 91                       Juliana Gomez            Juan David Ortiz Rendon              Mateo Ramírez Cabrera               Nicolas Navarro D.
# 101                      Natalia Perez                  Sofia Daza García              Tiffany Cardona Perez  Samuel Francisco Rubio Casallas
# 111   Daniel Esteban Ortegon Jaramillo                Juan Felipe Mahecha              Tiffany Cardona Perez            Esteban Sequeda Henao
# 124           César Camilo Díaz Cufiño               Laura Natalia Garcia                Sergio Gomez Osorio     Juan Sebastian Melo Gonzalez
# 133   Daniel Esteban Ortegon Jaramillo              Mateo Ramírez Cabrera           César Camilo Díaz Cufiño                        Pia Aroor
# 142       Juan Sebastian Melo Gonzalez          Alejandra Salazar Galeano      Sahily Andrea Herrera Eljadue  Samuel Francisco Rubio Casallas
# 154                          Pia Aroor         Luis Felipe Bonilla Patiño              Carlos Felipe Andrade             Laura Natalia Garcia
# 166   Daniel Esteban Ortegon Jaramillo                Juan Felipe Mahecha         Luis Felipe Bonilla Patiño            Mateo Ramírez Cabrera
# 176                          Juan Guio              Mateo Ramírez Cabrera                 Juan David Quitian               Nicolas Navarro D.
# 188                   Juan David Rubio         Luis Felipe Bonilla Patiño               Laura Natalia Garcia     Ángel Santiago Toribio Godoy
